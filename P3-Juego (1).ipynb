# %% [markdown]
# # PRACTICA 3
#
#
# ## JUEGO DE ADIVINANZAS
#
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %% [markdown]
# ##### PISTAS
# 1. Trata obtener un número aleatorio entre el 1 y el 100
# 2. Haz una introducción de tu juego y explica las reglas
# 3. Crea una lista que almacene los intentos.
# 4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
# 5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
import random

print("Bienvenido al Juego")
print("He pensado un número entre 1 y 100. ¡Intenta adivinarlo!")
print ("Reglas del juego:","\n","\t","1. Escoge un número entre 1 y 100 e introdúcelo en la caja de respuesta","\n","\t","2. Si el número no es válido, aparecerá 'FUERA DE LÍMITES' y tendrás que introducir otro número.","\n","\t", "3. Si el número es válido tras el primer intento:","\n","\t","\t","Cuando estás a 10 números de adivinarlo, saldrá el mensaje '¡CALIENTE!'","\n", "\t","\t", "Cuando estás más alejado, aparecerá '¡FRÍO!'","\n","\t","4. Si aciertas ¡ENHORABUENA! finalizaste el juego :)","\n","\t","    Si no aciertas, te pedirá un nuevo número. Dependiendo si estás más cerca o lejos, aparecerá '¡MÁS CALIENTE!' o '¡MÁS FRÍO!'","\n","Buena suerte y... ¡A JUGAR!")

def juego_adivina():
    num_adivinar = random.randint(1, 100)
    lista_intentos = []
    while True:
            try:
                intento = int(input("Introduce un número: "))
            except ValueError:
                print("Por favor introduce un número válido.")
                continue

            if intento <1 or intento >100:
              print("FUERA DE LÍMITES")
              continue

            if intento == num_adivinar:
                print("¡Muy bien! Has acertado en", len(lista_intentos)+1, "intentos." )
                break

            if len(lista_intentos) == 0:
              if abs(num_adivinar - intento) <=10:
                  print("¡CALIENTE!")
              else: print("¡FRÍO!")

            else:
                if abs(intento-num_adivinar) < abs(lista_intentos[-1]-num_adivinar):
                  print("¡MÁS CALIENTE!")
                else:
                  print("¡MÁS FRÍO!")
            lista_intentos.append(intento)

juego_adivina()
# Out:
# Bienvenido al Juego
# He pensado un número entre 1 y 100. ¡Intenta adivinarlo!
# Reglas del juego:
#  	 1. Escoge un número entre 1 y 100 e introdúcelo en la caja de respuesta
#  	 2. Si el número no es válido, aparecerá 'FUERA DE LÍMITES' y tendrás que introducir otro número.
#  	 3. Si el número es válido tras el primer intento:
#  	 	 Cuando estás a 10 números de adivinarlo, saldrá el mensaje '¡CALIENTE!'
#  	 	 Cuando estás más alejado, aparecerá '¡FRÍO!'
#  	 4. Si aciertas ¡ENHORABUENA! finalizaste el juego :)
#  	     Si no aciertas, te pedirá un nuevo número. Dependiendo si estás más cerca o lejos, aparecerá '¡MÁS CALIENTE!' o '¡MÁS FRÍO!'
#  Buena suerte y... ¡A JUGAR!
# Introduce un número: 40
# ¡FRÍO!
# Introduce un número: 30
# ¡MÁS FRÍO!
# Introduce un número: 80
# ¡MÁS CALIENTE!
# Introduce un número: 81
# ¡MÁS FRÍO!
# Introduce un número: 79
# ¡MÁS CALIENTE!
# Introduce un número: 78
# ¡MÁS CALIENTE!
# Introduce un número: 77
# ¡MÁS CALIENTE!
# Introduce un número: 76
# ¡MÁS CALIENTE!
# Introduce un número: 75
# ¡MÁS CALIENTE!
# Introduce un número: 74
# ¡MÁS CALIENTE!
# Introduce un número: 73
# ¡MÁS CALIENTE!
# Introduce un número: 72
# ¡MÁS CALIENTE!
# Introduce un número: 71
# ¡Muy bien! Has acertado en 13 intentos.
