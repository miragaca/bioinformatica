# %% [markdown]
# # PRACTICA 2
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"

# %%
cadena1 + cadena2
# Out:
# 'ATGCCTCCG'

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
len(dna)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena="mgXDyTw"

# %%
may = cadena.upper()
print("Cadena en mayúsculas:", may)
# Out:
# Cadena en mayúsculas: MGXDYTW

# %%
min = cadena.lower()
print("Cadena en minúsculas:", min)
# Out:
# Cadena en minúsculas: mgxdytw

# %%
long = len(cadena)
print("Longitud de cadena:", long)
# Out:
# Longitud de cadena: 7

# %%
dividir = cadena.split("g")
print("Dividida por 'g':", dividir)
# Out:
# Dividida por 'g': ['m', 'XDyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
nuevo_aa = aa.replace("v", "t")
print("Nueva secuencia:", nuevo_aa)
# Out:
# Nueva secuencia: tlspadktnt

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
len = aa.count("v")
print("Valinas de la secuencia anterior:", len)
# Out:
# Valinas de la secuencia anterior: 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
valor = enzR["BisI"]
print("Valor de BisI es:", valor)
# Out:
# Valor de BisI es: GC[ATGC]GC

# %%
enzR.pop("EcoRI")
# Out:
# 'GAATTC'

# %%
print("Diccionario después del pop:", enzR) #Con la función pop se elimina de forma permanente la key seleccionada, por ende no aparece
# Out:
# Diccionario después del pop: {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC"
dinucleotides = ['AA','AT','AG','AC',
                 'TA','TT','TG','TC',
                 'GA','GT','GG','GC',
                 'CA','CT','CG','CT']

# %%
num_din = {}
for din in dinucleotides:
  if din in num_din:
    num_din[din]+=1
  else:
    num_din[din]= 1
print(num_din)
# Out:
# {'AA': 1, 'AT': 1, 'AG': 1, 'AC': 1, 'TA': 1, 'TT': 1, 'TG': 1, 'TC': 1, 'GA': 1, 'GT': 1, 'GG': 1, 'GC': 1, 'CA': 1, 'CT': 2, 'CG': 1}

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
contar = dinucleotides.count("TC")
print("TC tiene", contar, "counts.")
# Out:
# TC tiene 1 counts.

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
for din in num_din:
  if num_din[din] == 2:
    print(din)
# Out:
# CT
